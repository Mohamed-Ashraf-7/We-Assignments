# %% [markdown]
# # Assignment 2 - Pandas Introduction
# All questions are weighted the same in this assignment.
# ## Part 1
# The following code loads the olympics dataset (olympics.csv), which was derrived from the Wikipedia entry on [All Time Olympic Games Medals](https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table), and does some basic data cleaning.
#
# The columns are organized as # of Summer games, Summer medals, # of Winter games, Winter medals, total # number of games, total # of medals. Use this dataset to answer the questions below.

# %%
import pandas as pd

df = pd.read_csv(r'C:\WEEE\We Assignments\Assignment 2 (census,olympics)\olympics - olympics.csv', index_col=0, skiprows=1)

# %%
New_df=df.copy()
New_df=New_df.rename(columns={'№ Summer':'Summer','№ Winter':'Winter','№ Games':'Games'})
New_df=New_df.drop(index='Totals')
New_df
# Out:
#                                               Summer  01 !  02 !  03 !  Total  \
# Afghanistan (AFG)                                 13     0     0     2      2
# Algeria (ALG)                                     12     5     2     8     15
# Argentina (ARG)                                   23    18    24    28     70
# Armenia (ARM)                                      5     1     2     9     12
# Australasia (ANZ) [ANZ]                            2     3     4     5     12
# ...                                              ...   ...   ...   ...    ...
# Yugoslavia (YUG) [YUG]                            16    26    29    28     83
# Independent Olympic Participants (IOP) [IOP]       1     0     1     2      3
# Zambia (ZAM) [ZAM]                                12     0     1     1      2
# Zimbabwe (ZIM) [ZIM]                              12     3     4     1      8
# Mixed team (ZZX) [ZZX]                             3     8     5     4     17
#
# ...

# %%
df
# Out:
#                                               № Summer  01 !  02 !  03 !  \
# Afghanistan (AFG)                                   13     0     0     2
# Algeria (ALG)                                       12     5     2     8
# Argentina (ARG)                                     23    18    24    28
# Armenia (ARM)                                        5     1     2     9
# Australasia (ANZ) [ANZ]                              2     3     4     5
# ...                                                ...   ...   ...   ...
# Independent Olympic Participants (IOP) [IOP]         1     0     1     2
# Zambia (ZAM) [ZAM]                                  12     0     1     1
# Zimbabwe (ZIM) [ZIM]                                12     3     4     1
# Mixed team (ZZX) [ZZX]                               3     8     5     4
# Totals                                              27  4809  4775  5130
#
#                                               Total  № Winter  01 !.1  02 !.1  \
# ...

# %% [markdown]
# ### Question 0 (Example)
#
# What is the first country in df?
#
# *This function should return a Series.*

# %%
def answer_zero():
    s=pd.Series(df.iloc[0])
    return s
answer_zero()
# Out:
# № Summer          13
# 01 !               0
# 02 !               0
# 03 !               2
# Total              2
# № Winter           0
# 01 !.1             0
# 02 !.1             0
# 03 !.1             0
# Total.1            0
# № Games           13
# 01 !.2             0
# 02 !.2             0
# 03 !.2             2
# Combined total     2
# Name: Afghanistan (AFG), dtype: int64

# %%
New_df
# Out:
#                                               Summer  01 !  02 !  03 !  Total  \
# Afghanistan (AFG)                                 13     0     0     2      2
# Algeria (ALG)                                     12     5     2     8     15
# Argentina (ARG)                                   23    18    24    28     70
# Armenia (ARM)                                      5     1     2     9     12
# Australasia (ANZ) [ANZ]                            2     3     4     5     12
# ...                                              ...   ...   ...   ...    ...
# Yugoslavia (YUG) [YUG]                            16    26    29    28     83
# Independent Olympic Participants (IOP) [IOP]       1     0     1     2      3
# Zambia (ZAM) [ZAM]                                12     0     1     1      2
# Zimbabwe (ZIM) [ZIM]                              12     3     4     1      8
# Mixed team (ZZX) [ZZX]                             3     8     5     4     17
#
# ...

# %%
for col in New_df.columns:
    if col[:2]=='01':
        New_df.rename(columns={col:'Gold'+col[4:]},inplace=True)
    if col[:2]=='02':
        New_df.rename(columns={col:'Silver'+col[4:]},inplace=True)
    if col[:2]=='03':
        New_df.rename(columns={col:'Bronze'+col[4:]},inplace=True)

# %%
New_df
# Out:
#                                               Summer  Gold  Silver  Bronze  \
# Afghanistan (AFG)                                 13     0       0       2
# Algeria (ALG)                                     12     5       2       8
# Argentina (ARG)                                   23    18      24      28
# Armenia (ARM)                                      5     1       2       9
# Australasia (ANZ) [ANZ]                            2     3       4       5
# ...                                              ...   ...     ...     ...
# Yugoslavia (YUG) [YUG]                            16    26      29      28
# Independent Olympic Participants (IOP) [IOP]       1     0       1       2
# Zambia (ZAM) [ZAM]                                12     0       1       1
# Zimbabwe (ZIM) [ZIM]                              12     3       4       1
# Mixed team (ZZX) [ZZX]                             3     8       5       4
#
# ...

# %% [markdown]
# ### Question 1
# Which country has won the most gold medals in summer games?
#
# *This function should return a single string value.*

# %%
def answer_one():
    Summer_players=New_df[New_df['Summer']>0]
    Gold_Summer_Winners=Summer_players[Summer_players['Gold']>1]
    return Summer_players['Gold'].idxmax()
answer_one()
# Out:
# 'United States\xa0(USA) [P] [Q] [R] [Z]'

# %% [markdown]
# ### Question 2
# Which country had the biggest difference between their summer and winter gold medal counts?
#
# *This function should return a single string value.*

# %%
def answer_two():
   New_df['Diff']=abs(New_df['Gold']-New_df['Gold.1'])
   return New_df['Diff'].idxmax()
answer_two()
# Out:
# 'United States\xa0(USA) [P] [Q] [R] [Z]'

# %% [markdown]
# ### Question 3
# Which country has the biggest difference between their summer gold medal counts and winter gold medal counts relative to their total gold medal count?
#
# $$\frac{Summer~Gold - Winter~Gold}{Total~Gold}$$
#
# Only include countries that have won at least 1 gold in both summer and winter.
#
# *This function should return a single string value.*

# %%
def answer_three():
   New_df['Total Gold']=New_df['Gold']+New_df['Gold.1']
   countries=New_df.copy().loc[(New_df['Gold']>=1) & (New_df['Gold.1']>=1),]
   countries['Real_diff']=countries['Diff']/countries['Total Gold']
   return countries['Real_diff'].idxmax()
answer_three()
# Out:
# 'Bulgaria\xa0(BUL) [H]'

# %% [markdown]
# ### Question 4
# Write a function that creates a Series called "Points" which is a weighted value where each gold medal (`Gold.2`) counts for 3 points, silver medals (`Silver.2`) for 2 points, and bronze medals (`Bronze.2`) for 1 point. The function should return only the column (a Series object) which you created, with the country names as indices.
#
# *This function should return a Series named `Points` of length 146*

# %%
def answer_four():
    Score=New_df['Gold.2']*3+New_df['Silver.2']*2+New_df['Bronze.2']*1
    return Score
answer_four()
# Out:
# Afghanistan (AFG)                                 2
# Algeria (ALG)                                    27
# Argentina (ARG)                                 130
# Armenia (ARM)                                    16
# Australasia (ANZ) [ANZ]                          22
#                                                ...
# Yugoslavia (YUG) [YUG]                          171
# Independent Olympic Participants (IOP) [IOP]      4
# Zambia (ZAM) [ZAM]                                3
# Zimbabwe (ZIM) [ZIM]                             18
# Mixed team (ZZX) [ZZX]                           38
# Length: 146, dtype: int64

# %% [markdown]
# ## Part 2
# For the next set of questions, we will be using census data from the [United States Census Bureau](http://www.census.gov). Counties are political and geographic subdivisions of states in the United States. This dataset contains population data for counties and states in the US from 2010 to 2015. [See this document](https://www2.census.gov/programs-surveys/popest/technical-documentation/file-layouts/2010-2015/co-est2015-alldata.pdf) for a description of the variable names.
#
# The census dataset (census.csv) should be loaded as census_df. Answer questions using this as appropriate.
#
# ### Question 5
# Which state has the most counties in it? (hint: consider the sumlevel key carefully! You'll need this for future questions too...)
#
# *This function should return a single string value.*

# %%
census_Original_df = pd.read_csv('census - census.csv')
census_Original_df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
census_Original_df['COUNTY'].describe()
# Out:
# count    3193.000000
# mean      101.918572
# std       107.626583
# min         0.000000
# 25%        33.000000
# 50%        77.000000
# 75%       133.000000
# max       840.000000
# Name: COUNTY, dtype: float64

# %%
def answer_five():
    State=census_Original_df.groupby('STNAME').count()
    return State['COUNTY'].idxmax()
answer_five()
# Out:
# 'Texas'

# %% [markdown]
# ### Question 6
# **Only looking at the three most populous counties for each state**, what are the three most populous states (in order of highest population to lowest population)? Use `CENSUS2010POP`.
#
# *This function should return a list of string values.*

# %%
def answer_six():
    sorted_Values=census_Original_df.sort_values(by='CENSUS2010POP',ascending=False)
    sorted_Values=sorted_Values[sorted_Values['SUMLEV']==50]
    return sorted_Values['STNAME'].iloc[:3]
answer_six()
# Out:
# 209     California
# 624       Illinois
# 2667         Texas
# Name: STNAME, dtype: object

# %%
census_Original_df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %% [markdown]
# ### Question 7
# Which county has had the largest absolute change in population within the period 2010-2015? (Hint: population values are stored in columns POPESTIMATE2010 through POPESTIMATE2015, you need to consider all six columns.)
#
# e.g. If County Population in the 5 year period is 100, 120, 80, 105, 100, 130, then its largest change in the period would be |130-80| = 50.
#
# *This function should return a single string value.*

# %%
def answer_seven():


    pop_columns = ['POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013', 'POPESTIMATE2014', 'POPESTIMATE2015']
    census_Original_df['pop_change'] = census_Original_df[pop_columns].max(axis=1) - census_Original_df[pop_columns].min(axis=1)
    max_change_row = census_Original_df.loc[census_Original_df['pop_change'].idxmax()]
    county_name = max_change_row['CTYNAME']
    state_name = max_change_row['STNAME']
    largest_change = max_change_row['pop_change']
    return print(f"The county with the largest absolute change in population is {county_name}, {state_name} with a change of {largest_change}.")

answer_seven()
# Out:
# The county with the largest absolute change in population is Texas, Texas with a change of 2224751.

# %% [markdown]
# ### Question 8
# In this datafile, the United States is broken up into four regions using the "REGION" column.
#
# Create a query that finds the counties that belong to regions 1 or 2, whose name starts with 'Washington', and whose POPESTIMATE2015 was greater than their POPESTIMATE 2014.
#
# *This function should return a 5x2 DataFrame with the columns = ['STNAME', 'CTYNAME'] and the same index ID as the census_df (sorted ascending by index).*

# %%
census_Original_df.head(20)
# Out:
#     SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME          CTYNAME  \
# 0       40       3         6      1       0  Alabama          Alabama
# 1       50       3         6      1       1  Alabama   Autauga County
# 2       50       3         6      1       3  Alabama   Baldwin County
# 3       50       3         6      1       5  Alabama   Barbour County
# 4       50       3         6      1       7  Alabama      Bibb County
# 5       50       3         6      1       9  Alabama    Blount County
# 6       50       3         6      1      11  Alabama   Bullock County
# 7       50       3         6      1      13  Alabama    Butler County
# 8       50       3         6      1      15  Alabama   Calhoun County
# 9       50       3         6      1      17  Alabama  Chambers County
# 10      50       3         6      1      19  Alabama  Cherokee County
# 11      50       3         6      1      21  Alabama   Chilton County
# ...

# %%
def answer_eight():
    Counties_1_2=census_Original_df[(census_Original_df['REGION']==1) | (census_Original_df['REGION']==2) ]
    Counties_1_2=Counties_1_2[Counties_1_2['CTYNAME'].str.startswith('Washington')]
    Counties_1_2=Counties_1_2[Counties_1_2['SUMLEV']==50]
    Counties_1_2=Counties_1_2[Counties_1_2['POPESTIMATE2015']>Counties_1_2['POPESTIMATE2014']]
    return Counties_1_2[['STNAME','CTYNAME']]
answer_eight()
# Out:
#             STNAME            CTYNAME
# 896           Iowa  Washington County
# 1419     Minnesota  Washington County
# 2345  Pennsylvania  Washington County
# 2355  Rhode Island  Washington County
# 3163     Wisconsin  Washington County
